# %% [markdown]
# # 1. Definition of GraphSAGE

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv, to_hetero

import random, numpy as np

import torch_geometric.transforms as T
from torch_geometric.datasets import OGB_MAG
from torch_geometric.loader import NeighborLoader

# %%
class HomoSAGE(nn.Module):
    """Homogeneous GraphSAGE backbone (to be replicated per relation by to_hetero)."""
    def __init__(self, hidden: int, out_dim: int, layers: int = 2,
                    dropout: float = 0.5, aggr: str = "mean", bn: bool = False):
        super().__init__()
        self.layers = layers
        self.dropout = dropout
        self.bns = nn.ModuleList()
        self.convs = nn.ModuleList()
        if layers == 1:
            self.convs.append(SAGEConv((-1, -1), out_dim, aggr=aggr))
        else:
            self.convs.append(SAGEConv((-1, -1), hidden, aggr=aggr))
            for _ in range(layers - 2):
                self.convs.append(SAGEConv((-1, -1), hidden, aggr=aggr))
            self.convs.append(SAGEConv((-1, -1), out_dim, aggr=aggr))
            if bn:
                for _ in range(layers - 1):
                    self.bns.append(nn.BatchNorm1d(hidden))
        self.use_bn = bn

    def forward(self, x, edge_index):
        h = x
        for i, conv in enumerate(self.convs[:-1]):
            h = conv(h, edge_index)
            if self.use_bn:
                h = self.bns[i](h)
            h = torch.relu(h)
            h = torch.dropout(h, p=self.dropout, train=self.training)
        h = self.convs[-1](h, edge_index)
        return h

def build_hetero_sage(metadata, hidden: int, out_dim: int, layers: int = 2,
                        dropout: float = 0.5, aggr: str = "mean",
                        bn: bool = False, aggr_rel: str = "sum"):
    """Wrap HomoSAGE into a heterogeneous operator via to_hetero."""
    backbone = HomoSAGE(hidden=hidden, out_dim=out_dim, layers=layers,
                        dropout=dropout, aggr=aggr, bn=bn)
    model = to_hetero(backbone, metadata=metadata, aggr=aggr_rel)
    return model

# %% [markdown]
# # 2. Utils

# %%
def resolve_device() -> torch.device:
    if torch.cuda.is_available():
        return torch.device("cuda")
    if torch.backends.mps.is_available() and torch.backends.mps.is_built():
        return torch.device("mps")
    return torch.device("cpu")

def set_seed(seed: int = 42, deterministic: bool = False) -> None:
    random.seed(seed); np.random.seed(seed); torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.benchmark = False
        torch.backends.cudnn.deterministic = deterministic
    if deterministic:
        torch.use_deterministic_algorithms(True, warn_only=True)

@torch.no_grad()
def masked_accuracy(logits: torch.Tensor, y: torch.Tensor, idx: torch.Tensor) -> float:
    if idx.numel() == 0: return float("nan")
    pred = logits[idx].argmax(-1)
    return (pred == y[idx]).float().mean().item()

# %%
device = resolve_device()

# %%
device
# Out:
# device(type='mps')

# %% [markdown]
# # 3. Load Data

# %%
def load_mag_hetero(root: str = "../data/ogb"):
    """
    Returns (data, y, split_idx, train_idx, valid_idx, test_idx)
    - data: object with x_dict, edge_index_dict, y_dict
    - y:    labels tensor for paper nodes (shape [N_paper])
    - split_idx: raw OGB split dict (for reference)
    """
    transform = T.ToUndirected(merge=True)
    ds = OGB_MAG(root, preprocess='metapath2vec', transform=transform)

    data = ds[0]
    y = data["paper"].y.view(-1)

    train_input_nodes = ('paper', data['paper'].train_mask)
    test_input_nodes = ('paper', data['paper'].test_mask)
    val_input_nodes = ('paper', data['paper'].val_mask)
    return ds, y, train_input_nodes, val_input_nodes, test_input_nodes

dataset, y, train_input_nodes, val_input_nodes, test_input_nodes = load_mag_hetero()
data = dataset[0]
num_classes = dataset.num_classes
data
# Out:
# HeteroData(
#   paper={
#     x=[736389, 128],
#     year=[736389],
#     y=[736389],
#     train_mask=[736389],
#     val_mask=[736389],
#     test_mask=[736389],
#   },
#   author={ x=[1134649, 128] },
#   institution={ x=[8740, 128] },
#   field_of_study={ x=[59965, 128] },
#   (author, affiliated_with, institution)={ edge_index=[2, 1043998] },
#   (author, writes, paper)={ edge_index=[2, 7145660] },
#   (paper, cites, paper)={ edge_index=[2, 10792672] },
#   (paper, has_topic, field_of_study)={ edge_index=[2, 7505078] },
#   (institution, rev_affiliated_with, author)={ edge_index=[2, 1043998] },
#   (paper, rev_writes, author)={ edge_index=[2, 7145660] },
#   (field_of_study, rev_has_topic, paper)={ edge_index=[2, 7505078] }
# )

# %%
data.metadata()
# Out:
# (['paper', 'author', 'institution', 'field_of_study'],
#  [('author', 'affiliated_with', 'institution'),
#   ('author', 'writes', 'paper'),
#   ('paper', 'cites', 'paper'),
#   ('paper', 'has_topic', 'field_of_study'),
#   ('institution', 'rev_affiliated_with', 'author'),
#   ('paper', 'rev_writes', 'author'),
#   ('field_of_study', 'rev_has_topic', 'paper')])

# %% [markdown]
# # 3. Setup

# %%
seed = 42

kwargs = {'batch_size': 1024, 'num_workers': 6, 'persistent_workers': True}

hidden = 128
layers = 2
agg = "mean"
aggr_rel = "sum"
neighbors = "15,10"

epochs = 50
lr = 0.01
batch_size = 2048
weight_decay = 5e-4
dropout = 0.5

# %% [markdown]
# # 4. Train

# %%
def make_loaders(data, train_input_nodes, val_input_nodes, test_input_nodes,
                    num_neighbors=(15, 10)):
    train_loader = NeighborLoader(
        data, num_neighbors=list(num_neighbors), shuffle=True,
        input_nodes=train_input_nodes, **kwargs)
    val_loader = NeighborLoader(
        data, num_neighbors=list(num_neighbors),
        input_nodes=val_input_nodes, **kwargs)

    return train_loader, val_loader

@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()
    all_logits = []
    all_idx = []
    for batch in loader:
        batch = batch.to(device)
        out_dict = model(batch.x_dict, batch.edge_index_dict)
        # first K entries in 'paper' correspond to seeds in this batch
        k = batch["paper"].batch_size
        logits = out_dict["paper"][:k]
        # map local seed nodes to global node indices:
        seed_nid = batch["paper"].n_id[:k]
        all_logits.append(logits.cpu())
        all_idx.append(seed_nid.cpu())
    return torch.cat(all_idx, dim=0), torch.cat(all_logits, dim=0)

# %%
def train(data, y, train_input_nodes, val_input_nodes, test_input_nodes):    

    model = build_hetero_sage(
        metadata=data.metadata(), hidden=hidden, out_dim=num_classes,
        layers=layers, dropout=dropout, aggr=agg, aggr_rel=aggr_rel
    ).to(device)

    # loaders
    num_neighbors = tuple(int(x) for x in neighbors.split(","))
    train_loader, val_loader = make_loaders(
        data, train_input_nodes, val_input_nodes, test_input_nodes, num_neighbors=num_neighbors
    )

    @torch.no_grad()
    def init_params():
        # Initialize lazy parameters via forwarding a single batch to the model:
        batch = next(iter(train_loader))
        batch = batch.to(device)
        model(batch.x_dict, batch.edge_index_dict)

    init_params()
    opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    best_val, best_state = 0.0, None
    for epoch in range(1, epochs + 1):
        model.train()
        total_loss = 0.0
        for batch in train_loader:
            batch = batch.to(device)
            out_dict = model(batch.x_dict, batch.edge_index_dict)
            k = batch["paper"].batch_size
            logits = out_dict["paper"][:k]
            y_seed = batch["paper"].y[:k]
            loss = F.cross_entropy(logits, y_seed)
            opt.zero_grad(set_to_none=True); loss.backward(); opt.step()
            total_loss += loss.item()

        # Eval
        val_idx_all, val_logits = evaluate(model, val_loader, device)
        #test_idx_all, test_logits = evaluate(model, test_loader, device)
        val_acc  = masked_accuracy(val_logits, y[val_idx_all], torch.arange(val_idx_all.numel()))
        #test_acc = masked_accuracy(test_logits, y[test_idx_all], torch.arange(test_idx_all.numel()))

        if val_acc > best_val:
            best_val, best_state = val_acc, {k: v.detach().cpu() for k, v in model.state_dict().items()}

        print(f"Epoch {epoch:03d} | loss {total_loss:.3f} | val {val_acc:.4f} ")

    #if best_state is not None:
        #model.load_state_dict(best_state, strict=True)
        #test_idx_all, test_logits = evaluate(model, test_loader, device)
        #final_test = masked_accuracy(test_logits, y[test_idx_all], torch.arange(test_idx_all.numel()))
        #print(f"[Best on val]  Final test acc: {final_test:.4f}")

# %%
train(data, y, train_input_nodes, val_input_nodes, test_input_nodes)
# Out:
# Epoch 001 | loss 1534.478 | val 0.3755
# Epoch 002 | loss 1368.777 | val 0.3899
# Epoch 003 | loss 1341.780 | val 0.3873
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 train(data, y, train_input_nodes, val_input_nodes, test_input_nodes)
#
# Cell In[28], line 31, in train(data, y, train_input_nodes, val_input_nodes, test_input_nodes)
#      29 for batch in train_loader:
#      30     batch = batch.to(device)
# ---> 31     out_dict = model(batch.x_dict, batch.edge_index_dict)
#      32     k = batch["paper"].batch_size
#      33     logits = out_dict["paper"][:k]
#
# File ~/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch/fx/graph_module.py:848, in GraphModule.recompile.<locals>.call_wrapped(self, *args, **kwargs)
#     847 def call_wrapped(self, *args, **kwargs):
# --> 848     return self._wrapped_call(self, *args, **kwargs)
#
# File ~/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch/fx/graph_module.py:411, in _WrappedCall.__call__(self, obj, *args, **kwargs)
#     409         return self.cls_call(obj, *args, **kwargs)
#     410     else:
# --> 411         return super(self.cls, obj).__call__(*args, **kwargs)  # type: ignore[misc]
#     412 except Exception as e:
#     413     assert e.__traceback__
#
# File ~/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File <eval_with_key>.15:21, in forward(self, x, edge_index)
#      19 convs_0__paper1 = getattr(self.convs, "0").author__writes__paper((x__author, x__paper), edge_index__author__writes__paper)
#      20 convs_0__paper2 = getattr(self.convs, "0").paper__cites__paper(x__paper, edge_index__paper__cites__paper)
# ---> 21 convs_0__field_of_study = getattr(self.convs, "0").paper__has_topic__field_of_study((x__paper, x__field_of_study), edge_index__paper__has_topic__field_of_study)
#      22 convs_0__author1 = getattr(self.convs, "0").institution__rev_affiliated_with__author((x__institution, x__author), edge_index__institution__rev_affiliated_with__author);  x__institution = None
#      23 convs_0__author2 = getattr(self.convs, "0").paper__rev_writes__author((x__paper, x__author), edge_index__paper__rev_writes__author);  x__author = None
#
# File ~/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch_geometric/nn/conv/sage_conv.py:134, in SAGEConv.forward(self, x, edge_index, size)
#     131     x = (self.lin(x[0]).relu(), x[1])
#     133 # propagate_type: (x: OptPairTensor)
# --> 134 out = self.propagate(edge_index, x=x, size=size)
#     135 out = self.lin_l(out)
#     137 x_r = x[1]
#
# File /var/folders/k6/18s4hr7n4xv6tk2jrjw6t3wr0000gn/T/torch_geometric.nn.conv.sage_conv_SAGEConv_propagate_z0pb4_54.py:229, in propagate(self, edge_index, x, size)
#     221             kwargs = CollectArgs(
#     222                 x_j=kwargs.x_j,
#     223                 index=hook_kwargs['index'],
#     224                 ptr=hook_kwargs['ptr'],
#     225                 dim_size=hook_kwargs['dim_size'],
#     226             )
#     227 # End Aggregate Forward Pre Hook #######################################
# --> 229 out = self.aggregate(
#     230     out,
#     231     index=kwargs.index,
#     232     ptr=kwargs.ptr,
#     233     dim_size=kwargs.dim_size,
#     234 )
#     236 # Begin Aggregate Forward Hook #########################################
#     237 if not torch.jit.is_scripting() and not is_compiling():
#
# File ~/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch_geometric/nn/conv/message_passing.py:594, in MessagePassing.aggregate(self, inputs, index, ptr, dim_size)
#     577 def aggregate(
#     578     self,
#     579     inputs: Tensor,
#    (...)
#     582     dim_size: Optional[int] = None,
#     583 ) -> Tensor:
#     584     r"""Aggregates messages from neighbors as
#     585     :math:`\bigoplus_{j \in \mathcal{N}(i)}`.
#     586
#    (...)
#     592     as specified in :meth:`__init__` by the :obj:`aggr` argument.
#     593     """
# --> 594     return self.aggr_module(inputs, index, ptr=ptr, dim_size=dim_size,
#     595                             dim=self.node_dim)
#
# File ~/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch_geometric/experimental.py:117, in disable_dynamic_shapes.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     114 @functools.wraps(func)
#     115 def wrapper(*args: Any, **kwargs: Any) -> Any:
#     116     if not is_experimental_mode_enabled('disable_dynamic_shapes'):
# --> 117         return func(*args, **kwargs)
#     119     for required_arg in required_args:
#     120         index = required_args_pos[required_arg]
#
# File ~/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch_geometric/nn/aggr/base.py:131, in Aggregation.__call__(self, x, index, ptr, dim_size, dim, **kwargs)
#     128     dim_size = int(index.max()) + 1 if index.numel() > 0 else 0
#     130 try:
# --> 131     return super().__call__(x, index=index, ptr=ptr, dim_size=dim_size,
#     132                             dim=dim, **kwargs)
#     133 except (IndexError, RuntimeError) as e:
#     134     if index is not None:
#
# File ~/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch_geometric/nn/aggr/basic.py:36, in MeanAggregation.forward(self, x, index, ptr, dim_size, dim)
#      33 def forward(self, x: Tensor, index: Optional[Tensor] = None,
#      34             ptr: Optional[Tensor] = None, dim_size: Optional[int] = None,
#      35             dim: int = -2) -> Tensor:
# ---> 36     return self.reduce(x, index, ptr, dim_size, dim, reduce='mean')
#
# File ~/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch_geometric/nn/aggr/base.py:185, in Aggregation.reduce(self, x, index, ptr, dim_size, dim, reduce)
#     182 if index is None:
#     183     raise RuntimeError("Aggregation requires 'index' to be specified")
# --> 185 return scatter(x, index, dim, dim_size, reduce)
#
# File ~/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch_geometric/utils/_scatter.py:74, in scatter(src, index, dim, dim_size, reduce)
#      72 if reduce == 'mean':
#      73     count = src.new_zeros(dim_size)
# ---> 74     count.scatter_add_(0, index, src.new_ones(src.size(dim)))
#      75     count = count.clamp(min=1)
#      77     index = broadcast(index, src, dim)
#
# KeyboardInterrupt:
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipelibc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
#
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe
# Traceback (most recent call last):
#   File "/Users/alei/.local/share/uv/python/cpython-3.10.18-macos-aarch64-none/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/alei/.local/share/uv/python/cpython-3.10.18-macos-aarch64-none/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/alei/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/alei/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/alei/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/Users/alei/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/alei/.local/share/uv/python/cpython-3.10.18-macos-aarch64-none/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/Users/alei/.local/share/uv/python/cpython-3.10.18-macos-aarch64-none/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/Users/alei/.local/share/uv/python/cpython-3.10.18-macos-aarch64-none/lib/python3.10/selectors.py", line 562, in select
#     kev_list = self._selector.control(None, max_ev, timeout)
#   File "/Users/alei/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 73, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 29887) is killed by signal: Abort trap: 6.
# Traceback (most recent call last):
#   File "/Users/alei/.local/share/uv/python/cpython-3.10.18-macos-aarch64-none/lib/python3.10/weakref.py", line 667, in _exitfunc
#     f()
#   File "/Users/alei/.local/share/uv/python/cpython-3.10.18-macos-aarch64-none/lib/python3.10/weakref.py", line 591, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/Users/alei/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch/library.py", line 482, in _del_library
#     m.reset()
#   File "/Users/alei/workspace/02456-Deep_Learning/GraphSSL/.venv/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 73, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 22138) is killed by signal: Abort trap: 6.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
